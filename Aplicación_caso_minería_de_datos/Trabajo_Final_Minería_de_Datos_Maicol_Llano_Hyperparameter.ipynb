# %% [markdown]
# # TRABAJO FINAL - MINERÍA DE DATOS
#
#
# #### Dataset: FIFA 18 More Complete Player Dataset
# #### Por: Maicol Llano Moncada

# %% [markdown]
# # Contenido
#
# 1. [Problema a resolver con los Datos](#1.-Problema-a-resolver-con-los-Datos)
#
#     - 1.1 [Descripción de los datos](#1.1-Descripción-de-los-datos)
#
#
# 2. [Importar Librerías](#2.-Importar-Librerías)
#
# 3. [Cargar Datos](#3.-Cargar-Datos)
#
# 4. [Descripción y limpieza de datos](#4.-Descripción-y-limpieza-de-datos)
#
#     - 4.1 [Descripción del dataset](#4.1-Descripción-del-dataset)
#
#     - 4.2 [Tipos de variables](#4.2-Tipos-de-variables)
#
#     - 4.3 [Datos duplicados](#4.3-Datos-duplicados)
#
#     - 4.4 [Variables sin utilidad](#4.4-Variables-sin-utilidad)
#
#     - 4.5 [Datos faltantes](#4.5-Datos-faltantes)
#
#     - 4.6 [Variables numéricas](#4.6-Variables-numéricas)
#
#     - 4.7 [Variables categóricas](#4.7-Variables-categóricas)
#
#     - 4.8 [Análisis Bivariable](#4.8-Análisis-Bivariable)
#
#     - 4.9 [Tratamiento de Outliers](#4.9-Tratamiento-de-Outliers)
#
#
# 5. [Feature Engineering](#5.-Feature-Engineering)
#
#     - 5.1 [Escalamiento - Transformación](#5.1-Escalamiento---Transformación)
#
#     - 5.2 [Creación de Variables](#5.2-Creación-de-Variables)
#
#     - 5.3 [Definición del dataframe para evaluar los modelos](#5.3-Definición-del-dataframe-para-evaluar-los-modelos)
#
#     - 5.4 [Análisis Bivariable con target](#5.4-Análisis-Bivariable-con-target)
#
#
# 6. [Aplicación de modelos de clasificación](#6.-Aplicación-de-modelos-de-clasificación-[predecir-la-posición])
#
#     - 6.1 [Visualización de resultados](#6.1-Visualización-de-resultados)
#
#     - 6.2 [Cross-Validation](#6.2-Cross-Validation)
#
#     - 6.3 [Visualización de resultados](#6.3-Visualización-de-resultados)
#
#     - 6.4 [Comparación de resultados](#6.4-Comparación-de-resultados)
#
#     - 6.5 [Hyperparameter Tunnig](#6.5-Hyperparameter-Tunnig)
#
#     - 6.6 [Evaluación con el dataframe de Test](#6.6-Evaluación-con-el-dataframe-de-Test)
#
#
# 7. [Aplicación de modelos de regresión](#7.-Aplicación-de-modelos-de-regresión-[predecir-el-precio])
#
#     - 7.1 [Visualización de resultados](#7.1-Visualización-de-resultados)
#
#     - 7.2 [Cross-Validation](#7.2-Cross-Validation)
#
#     - 7.3 [Visualización de resultados](#7.3-Visualización-de-resultados)
#
#     - 7.4 [Comparación de resultados](#7.4-Comparación-de-resultados)
#
#     - 7.5 [Hyperparameter Tunnig](#7.5-Hyperparameter-Tunnig)
#
#     - 7.6 [Evaluación con el dataframe de Test](#7.6-Evaluación-con-el-dataframe-de-Test)

# %% [markdown]
# # 1. Problema a resolver con los Datos
#
# Se parte de un dataset que contiene información acerca de las características de todos los jugadores que hacen parte
# del videojuego Fifa 18. A partir de estos datos se pretende realizar las siguientes tareas:
#
# - Determinar la posición de un jugador con base en sus habilidades y características
#
# - Determinar el precio de un jugador con base en sus habiliades y características

# %% [markdown]
# ## 1.1 Descripción de los datos

# %% [markdown]
# - Cantidad de variables: 185
# - Cantidad de instancias: 17994
#
# ### Significado de cada variable:
#
# ### Identificación:
#
# - ID: Identificador del jugador
# - name: Nombre del dorsal del jugador
# - full_name: Nombre completo del jugador
# - club: club en el que juega el jugador
# - club_logo: logo del club
# - special: identificador especial
# - age: edad del jugador
# - league: liga en la que juega
# - birth_date: fecha de nacimiento del jugador
# - height_cm: altura en centimetros
# - weight_kg: peso del jugador en kilogramos
# - body_type: tipo de cuerpo
# - real_face: el rostro que aparece en el juego es similar al real ?
# - flag: bandera del país del jugador
# - nationality: nacionalidad del jugador
# - photo: foto del jugador
#
# ### Monetarias:
#
# - eur_value: valor del pase del jugador en euros
# - eur_wage: salario de jugador en euros
# - eur_release_clause: clausula de recisión del contrato en euros
#
# ### Calificaciones y habilidades físicas/técnicas:
#
# - overall: puntaje global del jugador (0-100)
# - potential: pontencial de desarrollo de las habilidades del jugador (0-100)
# - pac: ritmo (0-100)
# - sho: tiro (0-100)
# - pas: pase (0-100)
# - dri: regate (0-100)
# - def: defensa (0-100)
# - phy: físico (0-100)
# - international_reputation: reputación internacional (1-5)
# - skill_moves: movimientos de regato
# - weak_foot: puntaje del pie débil
# - work_rate_att: tasa de ofensividad (L-H-M)
# - work_rate_def: tasa de defensa (L-H-M)
# - preferred_foot: pie preferido
# - crossing: cruces (0-100)
# - finishing: definición (0-100)
# - heading_accuracy: preicisón del cabeceo (0-100)
# - short_passing: pase corto (0-100)
# - volleys: boleas (0-100)
# - dribbling: regates (0-100)
# - curve: efecto del chute (0-100)
# - free_kick_accuracy: precisión del tiro libre (0-100)
# - long_passing: pase largo (0-100)
# - ball_control: control del balón
# - acceleration: aceleración
# - sprint_speed: velocidad en carrera (0-100)
# - agility: agilidad (0-100)
# - reactions: reacción (0-100)
# - balance: balance (0-100)
# - shot_power: fuerza del disparo (0-100)
# - jumping: salto (0-100)
# - stamina: estamina (0-100)
# - strength: fuerza (0-100)
# - long_shots: tiros lejanos (0-100)
# - aggression: agresividad (0-100)
# - interceptions: intercepciones (0-100)
# - positioning: posicionamiento (0-100)
# - vision: visión de juego (0-100)
# - penalties: penaltis (0-100)
# - composure: compostura (0-100)
# - marking: marcaje (0-100)
# - standing_tackle: entrada de pie (0-100)
# - sliding_tackle: entrada deslizante (0-100)
# - gk_diving: Estirada (arquero) (0-100)
# - gk_handling: atajada (arquero) (0-100)
# - gk_kicking: saque (arquero) (0-100)
# - gk_positioning: posicionamiento (arquero) (0-100)
# - gk_reflexes : reflejos (arquero) (0-100)
#
# ### Calificaciones por posición:
#
# - rs: puntaje en la posición de delantero derecho (0-100)
# - rw: puntaje en la posición de extremo derecho (0-100)
# - rf: puntaje en la posición de delantero derecho (0-100)
# - ram: puntaje en la posición de mediocampista ofensivo derecho (0-100)
# - rcm: puntaje en la posición de mediocampista central derecho  (0-100)
# - rm: puntaje en la posición de mediocampista derecho (0-100)
# - rdm: puntaje en la posición de mediocampista central defensivo derecho(0-100)
# - rcb: puntaje en la posición de central derecho (0-100)
# - rb: puntaje en la posición de lateral derecho (0-100)
# - rwb: puntaje en la posición de ala defensivo derecho retrasado (0-100)
# - st: puntaje en la posición de delantero (0-100)
# - lw: puntaje en la posición de extremo izquierdo (0-100)
# - cf: puntaje en la posición de centro delantero (0-100)
# - cam: puntaje en la posición de mediocampista ofensivo central (0-100)
# - cm: puntaje en la posición de mediocampista central (0-100)
# - lm: puntaje en la posición de mediocampista izquierdo (0-100)
# - cdm: puntaje en la posición de mediocampista central defensivo (0-100)
# - cb: puntaje en la posición de central (0-100)
# - lb: puntaje en la posición de lateral izquierdo (0-100)
# - lwb: puntaje en la posición de ala defensivo izquierda retrasado (0-100)
# - ls: puntaje en la posición de delantero izquierdo (0-100)
# - lf: puntaje en la posición de delantero izquierdo (0-100)
# - lam: puntaje en la posición de mediocampista izquierdo ofensivo (0-100)
# - lcm: puntaje en la posición de mediocampista central izquierdo (0-100)
# - ldm: puntaje en la posición de mediocampista central defensivo izquierdo (0-100)
# - lcb: puntaje en la posición de central izquiedo(0-100)
# - gk: puntaje en la posición de arquero (0-100)
#
# ### Rasgos
#
# - 1_on_1_rush_trait: Habilidad en uno contra uno (0-1)
# - acrobatic_clearance_trait: Acrobático (0-1)
# - argues_with_officials_trait: Discute con los árbittros (0-1)
# - avoids_using_weaker_foot_trait: Evita usar el pie débil (0-1)
# - backs_into_player_trait: Respalda a los compañeros (0-1)
# - bicycle_kicks_trait: TIros de bicicleta (0-1)
# - cautious_with_crosses_trait: Cuidadoso con los cruces (0-1)
# - chip_shot_trait: Tiro preciso (0-1)
# - chipped_penalty_trait: Penalti preciso (0-1)
# - comes_for_crosses_trait: Va a los cruces (0-1)
# - corner_specialist_trait: Especialista en tiros de esquina (0-1)
# - diver_trait: Simulador (0-1)
# - dives_into_tackles_trait: Se cae en las entradas (0-1)
# - diving_header_trait: Se cae en los cabezados (0-1)
# - driven_pass_trait: Pase en conducción (0-1)
# - early_crosser_trait: Cruce a tiempo (0-1)
# - fan's_favourite_trait: Favorito de los fans (0-1)
# - fancy_flicks_trait: toques de lujo (0-1)
# - finesse_shot_trait: tiros finos (0-1)
# - flair_trait: estilo (0-1)
# - flair_passes_trait: pases con estilo (0-1)
# - gk_flat_kick_trait: saque templado de arquero (0-1)
# - gk_long_throw_trait: saque largo de arquero (0-1)
# - gk_up_for_corners_trait: arquero que sube a los corners (0-1)
# - giant_throw_in_trait: saque de banda gigante (0-1)
# - inflexible_trait: poco flexible (0-1)
# - injury_free_trait: libre de lesiones (0-1)
# - injury_prone_trait: propenso a las lesiones (0-1)
# - leadership_trait: Lider (0-1)
# - long_passer_trait: Pases largos (0-1)
# - long_shot_taker_trait: Tiros largos (0-1)
# - long_throw_in_trait: Saque de manos largos (0-1)
# - one_club_player_trait: Jugador de un solo club (0-1)
# - outside_foot_shot_trait: Tiro con borde externo (0-1)
# - playmaker_trait: creador de juego (0-1)
# - power_free_kick_trait: tiro libre fuerte (0-1)
# - power_header_trait: cabezaso fuerte (0-1)
# - puncher_trait: golpeador (0-1)
# - rushes_out_of_goal_trait: corre fuera del area (0-1)
# - saves_with_feet_trait: salva con el pie (0-1)
# - second_wind_trait: segunda ala (0-1)
# - selfish_trait: egoista (0-1)
# - skilled_dribbling_trait: habilidoso para los regates (0-1)
# - stutter_penalty_trait: penaltis desviados (0-1)
# - swerve_pass_trait: pases desviados (0-1)
# - takes_finesse_free_kicks_trait: tiros libres finos (0-1)
# - target_forward_trait: va hacia adelante (0-1)
# - team_player_trait: jugador de equipo (0-1)
# - technical_dribbler_trait:  regateador técnico (0-1)
# - tries_to_beat_defensive_line_trait: trata de vencer la línea defensiva (0-1)
# - poacher_speciality: cazador (0-1)
# - speedster_speciality: especialisa en velocidad (0-1)
# - aerial_threat_speciality: amenaza aérea (0-1)
# - dribbler_speciality: especialista en regates (0-1)
# - playmaker_speciality: especialista en crear juego (0-1)
# - engine_speciality: motor del equipo (0-1)
# - distance_shooter_speciality: especialista en tiros a larga distancia (0-1)
# - crosser_speciality: especialista en cruces (0-1)
# - free_kick_specialist_speciality: especialista en tiros libres (0-1)
# - tackling_speciality: especialista en entradas (0-1)
# - tactician_speciality: especialista táctico (0-1)
# - acrobat_speciality: especialista en acrobacias (0-1)
# - strength_speciality: especialista en fuerza (0-1)
# - clinical_finisher_speciality: especialista en definiciones (0-1)
#
# ### Preferencias de posicionamiento en el campo:
#
# - prefers_rs: prefiere la posición rs (0-1)
# - prefers_rw: prefiere la posición rw (0-1)
# - prefers_rf: prefiere la posición rf (0-1)
# - prefers_ram: prefiere la posición ram (0-1)
# - prefers_rcm: prefiere la posición rcm (0-1)
# - prefers_rm: prefiere la posición rm (0-1)
# - prefers_rdm: prefiere la posición rdm (0-1)
# - prefers_rcb: prefiere la posición rcb (0-1)
# - prefers_rb: prefiere la posición rb (0-1)
# - prefers_rwb: prefiere la posición rwb (0-1)
# - prefers_st: prefiere la posición st (0-1)
# - prefers_lw: prefiere la posición lw (0-1)
# - prefers_cf: prefiere la posición cf (0-1)
# - prefers_cam: prefiere la posición cam (0-1)
# - prefers_cm: prefiere la posición cm (0-1)
# - prefers_lm: prefiere la posición lm (0-1)
# - prefers_cdm: prefiere la posición cdm (0-1)
# - prefers_cb: prefiere la posición cb (0-1)
# - prefers_lb: prefiere la posición lb (0-1)
# - prefers_lwb: prefiere la posición lwb (0-1)
# - prefers_ls: prefiere la posición ls (0-1)
# - prefers_lf: prefiere la posición lf (0-1)
# - prefers_lam: prefiere la posición lam (0-1)
# - prefers_lcm: prefiere la posición lcm (0-1)
# - prefers_ldm: prefiere la posición ldm (0-1)
# - prefers_lcb: prefiere la posición lcb (0-1)
# - prefers_gk: prefiere la posición gk (0-1)

# %% [markdown]
# ![fifa-18-Positions-Short-Forms-Terms-Abbreviations.jpg](attachment:fifa-18-Positions-Short-Forms-Terms-Abbreviations.jpg)

# %% [markdown]
# # 2. Importar Librerías

# %%
# Importar librerias

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import math
import warnings; warnings.simplefilter('ignore')
from IPython.core.display import HTML

# %% [markdown]
# # 3. Cargar Datos

# %%
#from google.colab import files
#uploaded = files.upload()

#import io
#data = io.BytesIO(uploaded['complete (2).csv'])  

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('drive/My Drive/complete.csv',encoding='utf_8')   

# Se observa el head del dataframe

df=df.iloc[0:1000]


display(HTML(df.head().to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>name</th>
#       <th>full_name</th>
#       <th>club</th>
#       <th>club_logo</th>
#       <th>special</th>
#       <th>age</th>
#       <th>league</th>
#       <th>birth_date</th>
#       <th>height_cm</th>
#       <th>weight_kg</th>
#       <th>body_type</th>
#       <th>real_face</th>
#       <th>flag</th>
#       <th>nationality</th>
#       <th>photo</th>
#       <th>eur_value</th>
#       <th>eur_wage</th>
#       <th>eur_release_clause</th>
#       <th>overall</th>
#       <th>potential</th>
#       <th>pac</th>
#       <th>sho</th>
#       <th>pas</th>
#       <th>dri</th>
#       <th>def</th>
#       <th>phy</th>
#       <th>international_reputation</th>
#       <th>skill_moves</th>
#       <th>weak_foot</th>
#       <th>work_rate_att</th>
#       <th>work_rate_def</th>
#       <th>preferred_foot</th>
#       <th>crossing</th>
# ...

# %%
# Se reservan estos registros para hacer algunas pruebas cuando se implementen los algoritmos de ML
#n=[0,1,7451,4,18,17,26,11,14]
n=[0,1,2,4,18,17,26,11,14]
zz=df.iloc[n]['name'].values

# %% [markdown]
# # 4. Descripción y limpieza de datos

# %% [markdown]
# ## 4.1 Descripción del dataset

# %%
#tamaño del dataframe

df.shape
# Out:
# (1000, 185)

# %%
print('Numero de instancias = {}'.format(len(df)))
# Out:
# Numero de instancias = 1000

# %%
# Realizar un analisis estadistico de las variables numéricas

display(HTML(df.describe().to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>special</th>
#       <th>age</th>
#       <th>height_cm</th>
#       <th>weight_kg</th>
#       <th>eur_value</th>
#       <th>eur_wage</th>
#       <th>eur_release_clause</th>
#       <th>overall</th>
#       <th>potential</th>
#       <th>pac</th>
#       <th>sho</th>
#       <th>pas</th>
#       <th>dri</th>
#       <th>def</th>
#       <th>phy</th>
#       <th>international_reputation</th>
#       <th>skill_moves</th>
#       <th>weak_foot</th>
#       <th>crossing</th>
#       <th>finishing</th>
#       <th>heading_accuracy</th>
#       <th>short_passing</th>
#       <th>volleys</th>
#       <th>dribbling</th>
#       <th>curve</th>
#       <th>free_kick_accuracy</th>
#       <th>long_passing</th>
#       <th>ball_control</th>
#       <th>acceleration</th>
#       <th>sprint_speed</th>
#       <th>agility</th>
#       <th>reactions</th>
# ...

# %% [markdown]
# ## 4.2 Tipos de variables

# %%
#Tipos de variables

print(df.dtypes.to_string())
# Out:
# ID                                      int64
# name                                   object
# full_name                              object
# club                                   object
# club_logo                              object
# special                                 int64
# age                                     int64
# league                                 object
# birth_date                             object
# height_cm                             float64
# weight_kg                             float64
# body_type                              object
# real_face                                bool
# flag                                   object
# nationality                            object
# photo                                  object
# eur_value                             float64
# eur_wage                              float64
# eur_release_clause                    float64
# overall                                 int64
# ...

# %% [markdown]
# ## 4.3 Datos duplicados

# %%
#Cantidad de datos duplicados

df[df.duplicated()==True].shape
# Out:
# (0, 185)

# %% [markdown]
# ## 4.4 Variables sin utilidad

# %%
delvars=['ID', 'name', 'full_name', 'club', 'club_logo', 'special','league', 
         'birth_date','body_type','real_face', 'flag', 'nationality', 'photo', 
         'eur_wage', 'eur_release_clause','international_reputation']

df.drop(delvars,1,inplace=True)

# %% [markdown]
# ## 4.5 Datos faltantes

# %%
#Se verifica cuáles variables tienen valores faltantes

df.isnull().sum()[df.isnull().sum()>0]
# Out:
# rs     113
# rw     113
# rf     113
# ram    113
# rcm    113
# rm     113
# rdm    113
# rcb    113
# rb     113
# rwb    113
# st     113
# lw     113
# cf     113
# cam    113
# cm     113
# lm     113
# cdm    113
# cb     113
# lb     113
# lwb    113
# ls     113
# lf     113
# lam    113
# lcm    113
# ldm    113
# lcb    113
# gk     887
# dtype: int64

# %%
# Cantidad de instancias con datos nulos

print(df.isnull().sum(axis=1)[df.isnull().sum(axis=1)>0].shape)
# Out:
# (1000,)

# %%
# Se identifica que los datos faltantes en las posiciones de campo, corresponden a registros de arqueros
# y que los datos faltantes en la posición de arquero corresponden a jugadores de campo.
# Se decide llenar estos datos faltantes con un valor de cero. 

df.fillna(0,inplace=True)

# %%
print(df.isnull().sum(axis=1)[df.isnull().sum(axis=1)>0].shape)
# Out:
# (0,)

# %% [markdown]
# ## 4.6 Variables numéricas

# %%
d=df.dtypes[df.dtypes=='float64'].index.values
e=df.dtypes[df.dtypes=='int64'].index.values

d=np.concatenate((d, e), axis=None)

fig, axes = plt.subplots(nrows=25, ncols=3, figsize=(20,100));
contador=0;
for x in range(25):
    for y in range(3):
        df[d[contador]].plot.hist(align='left',ec='black',ax=axes[x,y]);
        axes[x,y].set_title(d[contador])
        contador+=1
        if contador==75: break

# %% [markdown]
# ## 4.7 Variables categóricas

# %%
d=df.dtypes[df.dtypes=='object'].index.values
e=df.dtypes[df.dtypes=='bool'].index.values

d=np.concatenate((d, e), axis=None)

fig, axes = plt.subplots(nrows=32, ncols=3, figsize=(20,200));

contador=0;
for x in range(32):
    for y in range(3):
        df[d[contador]].value_counts().plot(kind='bar',ax=axes[x,y]);
        axes[x,y].set_title(d[contador])
        contador+=1
        if contador==94: break

# %% [markdown]
# ## 4.8 Análisis Bivariable

# %%
d=df.dtypes[df.dtypes=='float64'].index.values
e=df.dtypes[df.dtypes=='int64'].index.values

d=np.concatenate((d, e), axis=None)


mat_corr = df[d].corr()


mat_corr_int = (mat_corr>0.7).astype(int)

# Dibuja el heat map, donde los cuadros blancos serán donde hay una correlación > 0.7.
# De esta forma se validará entre qué variables tienen un cuadro BLANCO y estas se eliminarán
fig, axes = plt.subplots(figsize=(15, 15))
sns.heatmap(mat_corr_int, linewidths=.2, square=True, cbar=False);

# %% [markdown]
# ## 4.9 Tratamiento de Outliers

# %%
d=df.dtypes[df.dtypes=='float64'].index.values
e=df.dtypes[df.dtypes=='int64'].index.values

d=np.concatenate((d, e), axis=None)

fig, axes = plt.subplots(nrows=25, ncols=3, figsize=(20,100));
contador=0;
for x in range(25):
    for y in range(3):
        sns.boxplot(data=df[d[contador]],ax=axes[x,y])
        axes[x,y].set_title(d[contador])
        contador+=1
        if contador==75: break

# %% [markdown]
# # 5. Feature Engineering

# %% [markdown]
# ## 5.1 Escalamiento - Transformación

# %%
df['skill_moves']=df['skill_moves']*20 # Se escala esta variable para que quede entre 0 y 100
df['weak_foot']=df['weak_foot']*20     # Se escala esta variable para que quede entre 0 y 100

# Conversión de categórico a numérico

var=['work_rate_att','work_rate_def']

for i in var:
    df[i].replace('Low', 0, inplace=True)
    df[i].replace('Medium', 50, inplace=True)
    df[i].replace('High', 100, inplace=True)
    
df['preferred_foot'].replace('Left', 0, inplace=True)
df['preferred_foot'].replace('Right', 1, inplace=True)

# %%
# Conversión de booleano a numérico

boolean=df.dtypes[df.dtypes=='bool'].index.values
       
for i in boolean:
    df[i].replace(False, 0, inplace=True)
    df[i].replace(True, 1, inplace=True)

# %% [markdown]
# ##  5.2 Creación de Variables

# %%
# Se asume que la posición de un jugador es una de sus posiciones preferidas

preferedpos=['prefers_rs', 'prefers_rw', 'prefers_rf', 'prefers_ram',
'prefers_rcm', 'prefers_rm', 'prefers_rdm', 'prefers_rcb',
       'prefers_rb', 'prefers_rwb', 'prefers_st', 'prefers_lw',
       'prefers_cf', 'prefers_cam', 'prefers_cm', 'prefers_lm',
       'prefers_cdm', 'prefers_cb', 'prefers_lb', 'prefers_lwb',
       'prefers_ls', 'prefers_lf', 'prefers_lam', 'prefers_lcm',
       'prefers_ldm', 'prefers_lcb', 'prefers_gk']

pos=['rs', 'rw', 'rf', 'ram',
'rcm', 'rm', 'rdm', 'rcb',
       'rb', 'rwb', 'st', 'lw',
       'cf', 'cam', 'cm', 'lm',
       'cdm', 'cb', 'lb', 'lwb',
       'ls', 'lf', 'lam', 'lcm',
       'ldm', 'lcb', 'gk']

posiciones=[]

for i in range(len(df)):
    contador=0
    for j in range(len(preferedpos)):
        
        if df.iloc[i][preferedpos[contador]]==True:
            
            posiciones.append(pos[contador])
            break 
        
        contador=contador+1

# %%
# Se pasa la variable de posición a numérica teniendo en cuenta la siguiente distribución en el campo

# 0  --> Arquero
# 1  --> Defensas
# 2  --> Mediocampistas
# 3  --> Ofensivos

df['posicion']=posiciones
df['pos']=posiciones

        
df['pos'].replace('gk', 0, inplace=True)
df['pos'].replace(['lb','cb','rb'] , 1, inplace=True)
df['pos'].replace(['lwb','cdm','rwb','lm','cam','cm','rm'] , 2, inplace=True)
#df['pos'].replace(['lm','cam','cm','rm'] , 3, inplace=True)
df['pos'].replace(['lw','st','rw','cf'] , 3, inplace=True)

# %%
import seaborn as sns
#sns.set(style="darkgrid")

plt.figure(figsize=(15,8))
plt.title('Posiciones [cat]')
ax = sns.countplot(x='posicion', data=df)

for p in ax.patches: 
    if np.isnan(p.get_height()):
        height=0
    else: 
         height = p.get_height() 
            
    ax.text(p.get_x()+p.get_width()/2., 
      height + 3, 
      int(height), 
      ha="center")

# %%
plt.figure(figsize=(15,8))
plt.title('Posiciones [num]')
ax = sns.countplot(x='pos', data=df)

for p in ax.patches: 
    if np.isnan(p.get_height()):
        height=0
    else: 
         height = p.get_height() 
            
    ax.text(p.get_x()+p.get_width()/2., 
      height + 3, 
      int(height), 
      ha="center")

# %%
# Una vez determinada la posición ya no son necesarias las variables de preferencia

delvals=['prefers_rs', 'prefers_rw', 'prefers_rf', 'prefers_ram',
       'prefers_rcm', 'prefers_rm', 'prefers_rdm', 'prefers_rcb',
       'prefers_rb', 'prefers_rwb', 'prefers_st', 'prefers_lw',
       'prefers_cf', 'prefers_cam', 'prefers_cm', 'prefers_lm',
       'prefers_cdm', 'prefers_cb', 'prefers_lb', 'prefers_lwb',
       'prefers_ls', 'prefers_lf', 'prefers_lam', 'prefers_lcm',
       'prefers_ldm', 'prefers_lcb', 'prefers_gk']

df.drop(delvals,1,inplace=True)

# %%
display(HTML(df.head().to_html()))

## Se observa el dataframe que será usado para aplicar los modelos de ML
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>height_cm</th>
#       <th>weight_kg</th>
#       <th>eur_value</th>
#       <th>overall</th>
#       <th>potential</th>
#       <th>pac</th>
#       <th>sho</th>
#       <th>pas</th>
#       <th>dri</th>
#       <th>def</th>
#       <th>phy</th>
#       <th>skill_moves</th>
#       <th>weak_foot</th>
#       <th>work_rate_att</th>
#       <th>work_rate_def</th>
#       <th>preferred_foot</th>
#       <th>crossing</th>
#       <th>finishing</th>
#       <th>heading_accuracy</th>
#       <th>short_passing</th>
#       <th>volleys</th>
#       <th>dribbling</th>
#       <th>curve</th>
#       <th>free_kick_accuracy</th>
#       <th>long_passing</th>
#       <th>ball_control</th>
#       <th>acceleration</th>
#       <th>sprint_speed</th>
#       <th>agility</th>
#       <th>reactions</th>
#       <th>balance</th>
#       <th>shot_power</th>
# ...

# %% [markdown]
# ## 5.3 Definición del dataframe para evaluar los modelos

# %%
#n=[0,1,7451,4,18,17,26,11,14]
n=[0,1,2,4,18,17,26,11,14]

z=df.iloc[n][['age','overall','eur_value','posicion','pos']]

z['name']=zz

z
# Out:
#     age  overall    eur_value posicion  pos               name
# 0    32       94   95500000.0       st    3  Cristiano Ronaldo
# 1    30       93  105000000.0       rw    3           L. Messi
# 2    25       92  123000000.0       lw    3             Neymar
# 4    31       92   61000000.0       gk    0           M. Neuer
# 18   39       89    4500000.0       gk    0          G. Buffon
# 17   32       89   38000000.0       cb    1       G. Chiellini
# 26   31       88   40000000.0       cb    1           D. Godín
# 11   26       89   83000000.0       rm    2       K. De Bruyne
# 14   31       89   57000000.0       cm    2          L. Modrić

# %% [markdown]
# ## 5.4 Análisis Bivariable con target

# %%
d=df.dtypes[df.dtypes=='float64'].index.values
e=df.dtypes[df.dtypes=='int64'].index.values

d=np.concatenate((d, e), axis=None)


mat_corr = df[d].corr()


mat_corr_int = (mat_corr>0.7).astype(int)

# Dibuja el heat map, donde los cuadros blancos serán donde hay una correlación > 0.7.
# De esta forma se validará entre qué variables tienen un cuadro BLANCO y estas se eliminarán
fig, axes = plt.subplots(figsize=(15, 15))
sns.heatmap(mat_corr_int, linewidths=.2, square=True, cbar=False);

# %% [markdown]
# # 6. Aplicación de modelos de clasificación [predecir la posición]

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

#n=[0,1,7451,4,18,17,26,11,14]
n=[0,1,2,4,18,17,26,11,14]
cols=df.columns.values

xx=df[cols[1:-2]]
#xx=xx.drop(['eur_value'],1)
#display(HTML(xx.head().to_html()))
y = df['pos'].drop(df['pos'].index[n])

ScaleFn = MinMaxScaler()
xx = ScaleFn.fit_transform(xx)

g=[]

for item in n:
    g.append(xx[item])
    
xx= np.delete(xx, n,0)

# %%
from sklearn.cross_validation import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report,confusion_matrix


test_size = .30
seedNo = 42

x_train,X_test,y_train,Y_test = train_test_split(xx,y,test_size = test_size, random_state = seedNo)


# Choose algorithm and train
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import AdaBoostClassifier
import xgboost as xgb


from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

mymodel = []
mymodel.append(('LogReg', LogisticRegression()))
mymodel.append(('SVM', SVC()))
mymodel.append(('DeciTree', DecisionTreeClassifier()))
mymodel.append(('RandForest', RandomForestClassifier()))
mymodel.append(('KNN', KNeighborsClassifier()))
mymodel.append(('NaiveBayes', GaussianNB()))
mymodel.append(('Neuronal', MLPClassifier()))
mymodel.append(('XGBClassifier', xgb.XGBClassifier()))
mymodel.append(('AdaBoostClassifier', AdaBoostClassifier()))



resultados = {}
cm=[]
for algoname, algorithm in mymodel:    
    
    
    algorithm.fit(x_train,y_train)
    pred = algorithm.predict(X_test)
    
    Eval_result=accuracy_score(Y_test, pred)
    resultados[algoname]= Eval_result
    
    print("Modelo y precisión:", algoname, 100*Eval_result,"%")
    print("")
    print(classification_report(Y_test, pred))
    print("--------------------------------------------------------------")
    cmtemp=confusion_matrix(Y_test, pred)
    cm.append(cmtemp / cmtemp.astype(np.float).sum(axis=1,keepdims=True))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# Modelo y precisión: LogReg 82.21476510067114 %
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00        31
#           1       0.79      0.89      0.84        64
#           2       0.78      0.79      0.78       122
#           3       0.85      0.75      0.80        81
#
# avg / total       0.82      0.82      0.82       298
#
# --------------------------------------------------------------
# Modelo y precisión: SVM 81.87919463087249 %
#
#              precision    recall  f1-score   support
#
# ...

# %% [markdown]
# ## 6.1 Visualización de resultados

# %%
resultadosncv = pd.DataFrame.from_dict(resultados,orient='index')
resultadosncv.columns=["Accuracy"] 
resultadosncv = resultadosncv.sort_values(by=["Accuracy"],ascending=False)

resultadosncv
# Out:
#                     Accuracy
# Neuronal            0.842282
# RandForest          0.838926
# LogReg              0.822148
# XGBClassifier       0.822148
# SVM                 0.818792
# KNN                 0.761745
# DeciTree            0.755034
# NaiveBayes          0.721477
# AdaBoostClassifier  0.557047

# %%
resultadosncv[["Accuracy"]].plot.barh();
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5));

# %%
labels=['0','1', '2','3']
cmap=sns.diverging_palette(220,10,as_cmap=True)
fig, axes=plt.subplots(nrows=3, ncols=3, figsize=(20,20));
All_model_name=['LogisticRegression','SVM','DeciTree','RandForest','KNN','NaiveBayes','Neuronal','XGB','Adaboost']


contador=0;
for x in range(3):
    for y in range(3):
        try:
            sns.heatmap(cm[contador], annot=True, ax=axes[x,y], cmap=cmap); #annot=True to annotate cells
            # labels, title and ticks
            axes[x,y].set_xlabel('Predicted labels');axes[x,y].set_ylabel('True labels'); 
            axes[x,y].set_title(All_model_name[contador]); 
            axes[x,y].xaxis.set_ticklabels(labels); axes[x,y].yaxis.set_ticklabels(labels);
            contador+=1
            if contador==9: break
        except: pass

# %% [markdown]
# ## 6.2 Cross-Validation

# %%
import warnings; warnings.simplefilter('ignore')
seedNo = 42

#n=[0,1,7451,4,18,17,26,11,14]
n=[0,1,2,4,18,17,26,11,14]
cols=df.columns.values
xx=df[cols[:-2]]
y = df['pos'].drop(df['pos'].index[n])


ScaleFn = MinMaxScaler()
xx = ScaleFn.fit_transform(xx)

xx= np.delete(xx, n,0)

# Choose algorithm and train
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import AdaBoostClassifier
import xgboost as xgb


from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

mymodel = []
mymodel.append(('LogReg', LogisticRegression()))
mymodel.append(('SVM', SVC()))
mymodel.append(('DeciTree', DecisionTreeClassifier()))
mymodel.append(('RandForest', RandomForestClassifier()))
mymodel.append(('KNN', KNeighborsClassifier()))
mymodel.append(('NaiveBayes', GaussianNB()))
mymodel.append(('Neuronal', MLPClassifier()))
mymodel.append(('XGBClassifier', xgb.XGBClassifier()))
mymodel.append(('AdaBoostClassifier', AdaBoostClassifier()))


resultados={}

for algoname, algorithm in mymodel:    
    kfoldFn = KFold(n_splits = 10, random_state = seedNo)
    Eval_result = cross_val_score(algorithm, xx, y, cv = kfoldFn, scoring = 'accuracy')  
    resultados[algoname]=Eval_result.mean()

    print("Modelo y precisión:", algoname, 100*Eval_result.mean(),"%")
# Out:
# Modelo y precisión: LogReg 81.92727272727271 %
# Modelo y precisión: SVM 79.6131313131313 %
# Modelo y precisión: DeciTree 73.77272727272727 %
# Modelo y precisión: RandForest 80.11818181818182 %
# Modelo y precisión: KNN 78.91010101010102 %
# Modelo y precisión: NaiveBayes 71.83535353535355 %
# Modelo y precisión: Neuronal 81.42323232323233 %
# Modelo y precisión: XGBClassifier 82.34343434343432 %
# Modelo y precisión: AdaBoostClassifier 69.51717171717172 %

# %% [markdown]
# ## 6.3 Visualización de resultados

# %%
resultadoscv = pd.DataFrame.from_dict(resultados,orient='index')
resultadoscv.columns=["Accuracy-cv"] 
resultadoscv = resultadoscv.sort_values(by=["Accuracy-cv"],ascending=False)

resultadoscv
# Out:
#                     Accuracy-cv
# XGBClassifier          0.823434
# LogReg                 0.819273
# Neuronal               0.814232
# RandForest             0.801182
# SVM                    0.796131
# KNN                    0.789101
# DeciTree               0.737727
# NaiveBayes             0.718354
# AdaBoostClassifier     0.695172

# %%
resultadoscv[["Accuracy-cv"]].plot.barh();
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5));

# %% [markdown]
# ## 6.4 Comparación de resultados

# %%
## comparación

resultadosncv=resultadosncv.join(resultadoscv)

resultadosncv[["Accuracy", "Accuracy-cv"]].plot.barh()
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

# %%
resultadosncv
# Out:
#                     Accuracy  Accuracy-cv
# Neuronal            0.842282     0.814232
# RandForest          0.838926     0.801182
# LogReg              0.822148     0.819273
# XGBClassifier       0.822148     0.823434
# SVM                 0.818792     0.796131
# KNN                 0.761745     0.789101
# DeciTree            0.755034     0.737727
# NaiveBayes          0.721477     0.718354
# AdaBoostClassifier  0.557047     0.695172

# %% [markdown]
# ## 6.5 Hyperparameter Tuning

# %%
import warnings; warnings.simplefilter('ignore')
from sklearn.model_selection import GridSearchCV

# Create regularization penalty space
penalty = ['l1', 'l2']

# Create regularization hyperparameter space
C = np.logspace(0, 4, 10)

# Create hyperparameter options
hyperparameters = dict(C=C, penalty=penalty)


gridlogreg = GridSearchCV(LogisticRegression(), hyperparameters, cv=5, verbose=0, scoring='accuracy',return_train_score=True)
gridlogreg.fit(xx, y)
print(gridlogreg.best_estimator_)
#print(gridlogreg.score(xx,y))
print(gridlogreg.best_score_)


#---------------------------------------------------------------------------------------

# A parameter grid for XGBoost
'''
params = {
        'min_child_weight': [1, 5, 10],
        'gamma': [0.5, 1, 1.5, 2, 5],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [3, 4, 5]
        }

gridxg = GridSearchCV(xgb.XGBClassifier(), params, cv=5, verbose=0)
gridxg.fit(xx, y)
print(gridxg.best_estimator_)

'''

parameters = {
    'n_estimators'      : [320,330,340],
    'max_depth'         : [8, 9, 10, 11, 12],
    'random_state'      : [0,42,14],
    #'max_features': ['auto'],
    #'criterion' :['gini']
}

gridrff = GridSearchCV(RandomForestClassifier(), parameters, cv=5, n_jobs=-1,scoring='accuracy',return_train_score=True)
gridrff.fit(xx, y)
print(gridrff.best_estimator_)
#print(gridrff.score(xx,y))
print(gridrff.best_score_)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# 0.8213925327951564
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=8, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=330, n_jobs=1,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)
# 0.822401614530777

# %% [markdown]
# Los rendimientos aumentaron al realizar el hyperparameter optimization

# %% [markdown]
# ## 6.6 Evaluación con el dataframe de Test

# %%
#n=[0,1,7451,4,18,17,26,11,14]
n=[0,1,2,4,18,17,26,11,14]
cols=df.columns.values

xx=df[cols[1:-2]]
#xx=xx.drop(['eur_value'],1)
#display(HTML(xx.head().to_html()))
y = df['pos'].drop(df['pos'].index[n])

ScaleFn = MinMaxScaler()
xx = ScaleFn.fit_transform(xx)

    
xx= np.delete(xx, n,0)

algorithm=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
          intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
          penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
          verbose=0, warm_start=False)

algorithm.fit(xx,y)
pred = algorithm.predict(g)

print(pred)

z['pospred']=pred

z[['name','age','overall','eur_value','posicion','pos','pospred']]
# Out:
# [3 3 3 0 0 1 1 2 2]
#                  name  age  overall    eur_value posicion  pos  pospred
# 0   Cristiano Ronaldo   32       94   95500000.0       st    3        3
# 1            L. Messi   30       93  105000000.0       rw    3        3
# 2              Neymar   25       92  123000000.0       lw    3        3
# 4            M. Neuer   31       92   61000000.0       gk    0        0
# 18          G. Buffon   39       89    4500000.0       gk    0        0
# 17       G. Chiellini   32       89   38000000.0       cb    1        1
# 26           D. Godín   31       88   40000000.0       cb    1        1
# 11       K. De Bruyne   26       89   83000000.0       rm    2        2
# 14          L. Modrić   31       89   57000000.0       cm    2        2

# %% [markdown]
# # 7. Aplicación de modelos de regresión [predecir el precio]

# %%
df.columns.values
# Out:
# array(['age', 'height_cm', 'weight_kg', 'eur_value', 'overall',
#        'potential', 'pac', 'sho', 'pas', 'dri', 'def', 'phy',
#        'skill_moves', 'weak_foot', 'work_rate_att', 'work_rate_def',
#        'preferred_foot', 'crossing', 'finishing', 'heading_accuracy',
#        'short_passing', 'volleys', 'dribbling', 'curve',
#        'free_kick_accuracy', 'long_passing', 'ball_control',
#        'acceleration', 'sprint_speed', 'agility', 'reactions', 'balance',
#        'shot_power', 'jumping', 'stamina', 'strength', 'long_shots',
#        'aggression', 'interceptions', 'positioning', 'vision',
#        'penalties', 'composure', 'marking', 'standing_tackle',
#        'sliding_tackle', 'gk_diving', 'gk_handling', 'gk_kicking',
#        'gk_positioning', 'gk_reflexes', 'rs', 'rw', 'rf', 'ram', 'rcm',
#        'rm', 'rdm', 'rcb', 'rb', 'rwb', 'st', 'lw', 'cf', 'cam', 'cm',
#        'lm', 'cdm', 'cb', 'lb', 'lwb', 'ls', 'lf', 'lam', 'lcm', 'ldm',
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler


features=['age','height_cm', 'weight_kg', 'overall', 'potential',
       'pac', 'sho', 'pas', 'dri', 'def', 'phy', 'skill_moves',
       'weak_foot', 'work_rate_att', 'work_rate_def', 'preferred_foot',
       'crossing', 'finishing', 'heading_accuracy', 'short_passing',
       'volleys', 'dribbling', 'curve', 'free_kick_accuracy',
       'long_passing', 'ball_control', 'acceleration', 'sprint_speed',
       'agility', 'reactions', 'balance', 'shot_power', 'jumping',
       'stamina', 'strength', 'long_shots', 'aggression', 'interceptions',
       'positioning', 'vision', 'penalties', 'composure', 'marking',
       'standing_tackle', 'sliding_tackle', 'gk_diving', 'gk_handling',
       'gk_kicking', 'gk_positioning', 'gk_reflexes', 'rs', 'rw', 'rf',
       'ram', 'rcm', 'rm', 'rdm', 'rcb', 'rb', 'rwb', 'st', 'lw', 'cf',
       'cam', 'cm', 'lm', 'cdm', 'cb', 'lb', 'lwb', 'ls', 'lf', 'lam',
       'lcm', 'ldm', 'lcb', 'gk', '1_on_1_rush_trait',
       'acrobatic_clearance_trait', 'argues_with_officials_trait',
       'avoids_using_weaker_foot_trait', 'backs_into_player_trait',
       'bicycle_kicks_trait', 'cautious_with_crosses_trait',
       'chip_shot_trait', 'chipped_penalty_trait',
       'comes_for_crosses_trait', 'corner_specialist_trait',
       'diver_trait', 'dives_into_tackles_trait', 'diving_header_trait',
       'driven_pass_trait', 'early_crosser_trait',
       "fan's_favourite_trait", 'fancy_flicks_trait',
       'finesse_shot_trait', 'flair_trait', 'flair_passes_trait',
       'gk_flat_kick_trait', 'gk_long_throw_trait',
       'gk_up_for_corners_trait', 'giant_throw_in_trait',
       'inflexible_trait', 'injury_free_trait', 'injury_prone_trait',
       'leadership_trait', 'long_passer_trait', 'long_shot_taker_trait',
       'long_throw_in_trait', 'one_club_player_trait',
       'outside_foot_shot_trait', 'playmaker_trait',
       'power_free_kick_trait', 'power_header_trait', 'puncher_trait',
       'rushes_out_of_goal_trait', 'saves_with_feet_trait',
       'second_wind_trait', 'selfish_trait', 'skilled_dribbling_trait',
       'stutter_penalty_trait', 'swerve_pass_trait',
       'takes_finesse_free_kicks_trait', 'target_forward_trait',
       'team_player_trait', 'technical_dribbler_trait',
       'tries_to_beat_defensive_line_trait', 'poacher_speciality',
       'speedster_speciality', 'aerial_threat_speciality',
       'dribbler_speciality', 'playmaker_speciality', 'engine_speciality',
       'distance_shooter_speciality', 'crosser_speciality',
       'free_kick_specialist_speciality', 'tackling_speciality',
       'tactician_speciality', 'acrobat_speciality',
       'strength_speciality', 'clinical_finisher_speciality']

xx=df[features]
#n=[0,1,7451,4,18,17,26,11,14]
n=[0,1,2,4,18,17,26,11,14]
y = df['eur_value'].drop(df['eur_value'].index[n])


ScaleFn = MinMaxScaler()
xx = ScaleFn.fit_transform(xx)
xx= np.delete(xx, n,0)

# %%
import warnings; warnings.simplefilter('ignore')
test_size = .30
seedNo = 42

x_train,x_test,y_train,Y_test = train_test_split(xx,y,test_size = test_size, random_state = seedNo)

# %%
# Choose algorithm and train
from sklearn import linear_model
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import AdaBoostRegressor
import xgboost as xgb


from sklearn.metrics import r2_score
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score


mymodel = []
mymodel.append(('Regr. Lineal', linear_model.LinearRegression()))
mymodel.append(('DecisionTreeRegressor', DecisionTreeRegressor()))
mymodel.append(('RandomForestRegressor', RandomForestRegressor()))
mymodel.append(('SVR', SVR()))
mymodel.append(('MLPRegressor', MLPRegressor()))
mymodel.append(('AdaBoostRegressor', AdaBoostRegressor()))
mymodel.append(('XGBRegressor', xgb.XGBRegressor()))



resultados={}

for algoname, algorithm in mymodel:  
    
    algorithm.fit(x_train,y_train)
    pred = algorithm.predict(x_test)
    Eval_result=r2_score(Y_test, pred)
    resultados[algoname]=Eval_result
    
    
    print("Modelo y R2:", algoname, 100*Eval_result,"%")
# Out:
# Modelo y R2: Regr. Lineal 86.6877621770062 %
# Modelo y R2: DecisionTreeRegressor 82.69322806401453 %
# Modelo y R2: RandomForestRegressor 92.70586734906385 %
# Modelo y R2: SVR -9.000083437576745 %
# Modelo y R2: MLPRegressor -212.98943576214003 %
# Modelo y R2: AdaBoostRegressor 88.77460820322362 %
# Modelo y R2: XGBRegressor 96.11410877877987 %

# %% [markdown]
# ## 7.1 Visualización de resultados

# %%
resultadosncv= pd.DataFrame.from_dict(resultados,orient='index')
resultadosncv.columns=["R Square - Default"] 
resultadosncv = resultadosncv.sort_values(by=["R Square - Default"],ascending=False)

resultadosncv
# Out:
#                        R Square - Default
# XGBRegressor                     0.961141
# RandomForestRegressor            0.927059
# AdaBoostRegressor                0.887746
# Regr. Lineal                     0.866878
# DecisionTreeRegressor            0.826932
# SVR                             -0.090001
# MLPRegressor                    -2.129894

# %%
resultadosncv[["R Square - Default"]].plot.barh();
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5));

# %% [markdown]
# ## 7.2 Cross Validation

# %%
import warnings; warnings.simplefilter('ignore')

xx=df[features]
#n=[0,1,7451,4,18,17,26,11,14]
n=[0,1,2,4,18,17,26,11,14]
y = df['eur_value'].drop(df['eur_value'].index[n])


ScaleFn = MinMaxScaler()
xx = ScaleFn.fit_transform(xx)
xx= np.delete(xx, n,0)

seedNo = 42

from sklearn import linear_model
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import AdaBoostRegressor
import xgboost as xgb



from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score


mymodel = []
mymodel.append(('Regr. Lineal', linear_model.LinearRegression()))
mymodel.append(('DecisionTreeRegressor', DecisionTreeRegressor()))
mymodel.append(('RandomForestRegressor', RandomForestRegressor()))
mymodel.append(('SVR', SVR()))
mymodel.append(('MLPRegressor', MLPRegressor()))
mymodel.append(('AdaBoostRegressor', AdaBoostRegressor()))
mymodel.append(('XGBRegressor', xgb.XGBRegressor()))


resultados={}
for algoname, algorithm in mymodel:  
    
    algorithm.fit(xx,y)
    kfoldFn = KFold(n_splits = 10, random_state = seedNo)
    Eval_result2 = cross_val_score(algorithm, xx, y, cv = kfoldFn, scoring = 'r2')
    Ev=np.mean((Eval_result2))
    resultados[algoname]=Ev
    
    print("Modelo y R2:", algoname, 100*Ev,"%")
# Out:
# Modelo y R2: Regr. Lineal -7.866334321397527e+18 %
# Modelo y R2: DecisionTreeRegressor 8.666643243298347 %
# Modelo y R2: RandomForestRegressor 40.38698055507678 %
# Modelo y R2: SVR -203.0751237448569 %
# Modelo y R2: MLPRegressor -1316.2421988853496 %
# Modelo y R2: AdaBoostRegressor -4.75518338443212 %
# Modelo y R2: XGBRegressor 50.97900409909042 %

# %% [markdown]
# ## 7.3 Visualización de resultados

# %%
resultadoscv = pd.DataFrame.from_dict(resultados,orient='index')
resultadoscv.columns=["R Square - CV"] 
resultadoscv = resultadoscv.sort_values(by=["R Square - CV"],ascending=False)

resultadoscv
# Out:
#                        R Square - CV
# XGBRegressor            5.097900e-01
# RandomForestRegressor   4.038698e-01
# DecisionTreeRegressor   8.666643e-02
# AdaBoostRegressor      -4.755183e-02
# SVR                    -2.030751e+00
# MLPRegressor           -1.316242e+01
# Regr. Lineal           -7.866334e+16

# %%
#resultadoscv[["R Square - CV"]].plot.barh();
#plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5));

# %% [markdown]
# ## 7.4 Comparación de resultados

# %%
## comparación

resultadosncv=resultadosncv.join(resultadoscv)

#resultadosncv[["R Square - Default", "R Square - CV"]].plot.barh()
#plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

resultadosncv
# Out:
#                        R Square - Default  R Square - CV
# XGBRegressor                     0.961141   5.097900e-01
# RandomForestRegressor            0.927059   4.038698e-01
# AdaBoostRegressor                0.887746  -4.755183e-02
# Regr. Lineal                     0.866878  -7.866334e+16
# DecisionTreeRegressor            0.826932   8.666643e-02
# SVR                             -0.090001  -2.030751e+00
# MLPRegressor                    -2.129894  -1.316242e+01

# %% [markdown]
# ## 7.5 Hyperparameter Tuning

# %%
parameters = {
    'n_estimators'      : [320,330,340],
    'max_depth'         : [8, 9, 10, 11, 12],
    'random_state'      : [0,42,14],
    #'max_features': ['auto'],
    #'criterion' :['gini']
}

gridrf = GridSearchCV(RandomForestRegressor(), parameters, cv=5, n_jobs=-1,scoring='r2',return_train_score=True)
gridrf.fit(xx, y)
print(gridrf.best_estimator_)
#print(gridrf.score(xx,y))
print(gridrf.best_score_)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=12,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=330, n_jobs=1,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)
# 0.35512101664801826

# %% [markdown]
# En este caso se observa que el rendimiento se redujo

# %% [markdown]
# ## 7.6 Evaluación con el dataframe de Test

# %%
xx=df[features]
#n=[0,1,7451,4,18,17,26,11,14]
n=[0,1,2,4,18,17,26,11,14]
y = df['eur_value'].drop(df['eur_value'].index[n])


ScaleFn = MinMaxScaler()
xx = ScaleFn.fit_transform(xx)

g=[]

for item in n:
    g.append(xx[item])
    
xx= np.delete(xx, n,0)




algorithm=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=12,
           max_features='auto', max_leaf_nodes=None,
           min_impurity_decrease=0.0, min_impurity_split=None,
           min_samples_leaf=1, min_samples_split=2,
           min_weight_fraction_leaf=0.0, n_estimators=330, n_jobs=1,
           oob_score=False, random_state=0, verbose=0, warm_start=False)

algorithm.fit(xx,y)
pred = algorithm.predict(g)

z['valpred']=pred

z[['name','age','overall','eur_value','valpred','posicion','pos','pospred']]
# Out:
#                  name  age  overall    eur_value       valpred posicion  pos  \
# 0   Cristiano Ronaldo   32       94   95500000.0  8.636667e+07       st    3
# 1            L. Messi   30       93  105000000.0  8.208939e+07       rw    3
# 2              Neymar   25       92  123000000.0  7.876279e+07       lw    3
# 4            M. Neuer   31       92   61000000.0  6.032424e+07       gk    0
# 18          G. Buffon   39       89    4500000.0  4.932879e+07       gk    0
# 17       G. Chiellini   32       89   38000000.0  5.029712e+07       cb    1
# 26           D. Godín   31       88   40000000.0  3.644561e+07       cb    1
# 11       K. De Bruyne   26       89   83000000.0  7.207273e+07       rm    2
# 14          L. Modrić   31       89   57000000.0  6.254877e+07       cm    2
#
#     pospred
# 0         3
# 1         3
# 2         3
# 4         0
# 18        0
# 17        1
# 26        1
# 11        2
# 14        2
